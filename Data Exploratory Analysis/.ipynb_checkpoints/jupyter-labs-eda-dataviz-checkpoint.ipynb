# %% [markdown]
# # **SpaceX  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# Most unsuccessful landings are planned. Space X performs a controlled landing in the oceans.

# %% [markdown]
#   ## Objectives
# Perform exploratory Data Analysis and Feature Engineering using `Pandas` and `Matplotlib`
#
# - Exploratory Data Analysis
# - Preparing Data  Feature Engineering

# %% [markdown]
# ----

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# First, let's read the SpaceX dataset into a Pandas dataframe and print its summary

# %%
df = pd.read_csv('C:\\Users\\LENOVO\\Desktop\\DS\\10\\capstone\\Capstone-master\\Data Wrangling\\dataset_part_2.csv')

df.head(5)
# Out:
#    FlightNumber        Date BoosterVersion  \
# 0             1  2010-06-04       Falcon 9
# 1             2  2012-05-22       Falcon 9
# 2             3  2013-03-01       Falcon 9
# 3             4  2013-09-29       Falcon 9
# 4             5  2013-12-03       Falcon 9
#
#                                          PayloadMass Orbit    LaunchSite  \
# 0  <bound method NDFrame._add_numeric_operations....   LEO  CCSFS SLC 40
# 1                                              525.0   LEO  CCSFS SLC 40
# 2                                              677.0   ISS  CCSFS SLC 40
# 3                                              500.0    PO   VAFB SLC 4E
# 4                                             3170.0   GTO  CCSFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Class
# 0            0  B0003  -80.577366  28.561857      0
# 1            0  B0005  -80.577366  28.561857      0
# 2            0  B0007  -80.577366  28.561857      0
# 3            0  B1003 -120.610829  34.632093      0
# 4            0  B1004  -80.577366  28.561857      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   FlightNumber    90 non-null     int64
#  1   Date            90 non-null     object
#  2   BoosterVersion  90 non-null     object
#  3   PayloadMass     90 non-null     object
#  4   Orbit           90 non-null     object
#  5   LaunchSite      90 non-null     object
#  6   Outcome         90 non-null     object
#  7   Flights         90 non-null     int64
#  8   GridFins        90 non-null     bool
#  9   Reused          90 non-null     bool
#  10  Legs            90 non-null     bool
#  11  LandingPad      64 non-null     object
#  12  Block           90 non-null     float64
#  13  ReusedCount     90 non-null     int64
#  14  Serial          90 non-null     object
#  15  Longitude       90 non-null     float64
#  16  Latitude        90 non-null     float64
#  17  Class           90 non-null     int64
# dtypes: bool(3), float64(3), int64(4), object(8)
# memory usage: 10.9+ KB

# %% [markdown]
# First, let's try to see how the `FlightNumber` (indicating the continuous launch attempts.) and `Payload` variables would affect the launch outcome.
#
# We can plot out the <code>FlightNumber</code> vs. <code>PayloadMass</code>and overlay the outcome of the launch. We see that as the flight number increases, the first stage is more likely to land successfully. The payload mass is also important; it seems the more massive the payload, the less likely the first stage will return.

# %%
sns.catplot(y="PayloadMass", x="FlightNumber", hue="Class", data=df, aspect = 5)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("Pay load Mass (kg)",fontsize=20)
plt.show()

# %% [markdown]
# We see that different launch sites have different success rates.  <code>CCAFS LC-40</code>, has a success rate of 60 %, while  <code>KSC LC-39A</code> and <code>VAFB SLC 4E</code> has a success rate of 77%.

# %% [markdown]
# Next, let's drill down to each site visualize its detailed launch records.

# %% [markdown]
# ###  Visualize the relationship between Flight Number and Launch Site

# %%
# Plot a scatter point chart with x axis to be Flight Number and y axis to be the launch site, and hue to be the class value
sns.catplot(y="LaunchSite", x="FlightNumber", hue="Class", data=df, aspect = 5)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("Pay load Mass (kg)",fontsize=20)
plt.show()

# %% [markdown]
# ### Visualize the relationship between Payload and Launch Site

# %% [markdown]
# We also want to observe if there is any relationship between launch sites and their payload mass.

# %%
# Plot a scatter point chart with x axis to be Pay Load Mass (kg) and y axis to be the launch site, and hue to be the class value
plt.figure(figsize=(10,10))
sns.catplot(y="LaunchSite", x="PayloadMass", hue="Class", data=df, aspect = 5)

plt.show()

# %% [markdown]
# Now if you observe Payload Vs. Launch Site scatter point chart you will find for the VAFB-SLC  launchsite there are no  rockets  launched for  heavypayload mass(greater than 10000).

# %% [markdown]
# ###  Visualize the relationship between success rate of each orbit type

# %% [markdown]
# Next, we want to visually check if there are any relationship between success rate and orbit type.

# %% [markdown]
# Let's create a `bar chart` for the sucess rate of each orbit

# %%
# HINT use groupby method on Orbit column and get the mean of Class column
plt.pie(df.groupby('Orbit')['Class'].mean(), labels = df.groupby('Orbit')['Class'].mean().keys())
# Out:
# ([<matplotlib.patches.Wedge at 0x1b608d84460>,
#   <matplotlib.patches.Wedge at 0x1b608d84c40>,
#   <matplotlib.patches.Wedge at 0x1b608d84cd0>,
#   <matplotlib.patches.Wedge at 0x1b608d920a0>,
#   <matplotlib.patches.Wedge at 0x1b608d923a0>,
#   <matplotlib.patches.Wedge at 0x1b608d92550>,
#   <matplotlib.patches.Wedge at 0x1b608d928b0>,
#   <matplotlib.patches.Wedge at 0x1b608bab220>,
#   <matplotlib.patches.Wedge at 0x1b608bab970>,
#   <matplotlib.patches.Wedge at 0x1b608ba3eb0>,
#   <matplotlib.patches.Wedge at 0x1b608d84430>],
#  [Text(1.0171353519677202, 0.41885042172296105, 'ES-L1'),
#   Text(0.4272450120350107, 1.0136378543105047, 'GEO'),
#   Text(-0.21236906496719513, 1.0793050450382224, 'GTO'),
#   Text(-0.7794234164441322, 0.7762081794844454, 'HEO'),
#   Text(-1.0875032576832022, 0.1653380311012042, 'ISS'),
#   Text(-1.0255744271775376, -0.3977399833050055, 'LEO'),
#   Text(-0.675633906963032, -0.8680546202641105, 'MEO'),
#   Text(-0.15409083118644187, -1.0891538072027622, 'PO'),
#   Text(0.13154877642286275, -1.0921057272176755, 'SO'),
#   Text(0.5374835049263412, -0.9597455297796891, 'SSO'),
#   Text(1.0389137198282548, -0.3614668487601855, 'VLEO')])

# %% [markdown]
# Analyze the ploted bar chart try to find which orbits have high sucess rate.

# %% [markdown]
# ### Visualize the relationship between FlightNumber and Orbit type

# %% [markdown]
# For each orbit, we want to see if there is any relationship between FlightNumber and Orbit type.

# %%
# Plot a scatter point chart with x axis to be FlightNumber and y axis to be the Orbit, and hue to be the class value
sns.catplot(y="Orbit", x="FlightNumber", hue="Class", data=df)

plt.show()

# %% [markdown]
# You should see that in the LEO orbit the Success appears related to the number of flights; on the other hand, there seems to be no relationship between flight number when in GTO orbit.

# %% [markdown]
# ###  Visualize the relationship between Payload and Orbit type

# %% [markdown]
# Similarly, we can plot the Payload vs. Orbit scatter point charts to reveal the relationship between Payload and Orbit type

# %%
# Plot a scatter point chart with x axis to be Payload and y axis to be the Orbit, and hue to be the class value
sns.scatterplot(y="Orbit", x="PayloadMass", hue="Class", data=df)

plt.show()

# %% [markdown]
# With heavy payloads the successful landing or positive landing rate are more for Polar,LEO and ISS.
#
# However for GTO we cannot distinguish this well as both positive landing rate and negative landing(unsuccessful mission) are both there here.

# %% [markdown]
# ### Visualize the launch success yearly trend

# %%
# A function to Extract years from the date 
year=[]
def Extract_year(date):
    for i in df["Date"]:
        year.append(i.split("-")[0])
    return year

# %%
year = Extract_year(df)
print(year)
# Out:
# ['2010', '2012', '2013', '2013', '2013', '2014', '2014', '2014', '2014', '2014', '2014', '2015', '2015', '2015', '2015', '2015', '2015', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2016', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2018', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2019', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020', '2020']

# %%
# Plot a line chart with x axis to be the extracted year and y axis to be the success rate
plt.figure(figsize=(15,5))
sns.lineplot(x=year, y="Class", data=df)

plt.show()

# %% [markdown]
# You can observe that the success rate since 2013 kept increasing till 2017 (stable in 2014) and after 2015 it started increasing.

# %% [markdown]
# ## Features Engineering

# %% [markdown]
# By now, we should obtain some preliminary insights about how each important variable would affect the success rate, we will select the features that will be used in success prediction in the future module.

# %%
features = df[['FlightNumber', 'PayloadMass', 'Orbit', 'LaunchSite', 'Flights', 'GridFins', 'Reused', 'Legs', 'LandingPad', 'Block', 'ReusedCount', 'Serial']]
features.head()
# Out:
#    FlightNumber                                        PayloadMass Orbit  \
# 0             1  <bound method NDFrame._add_numeric_operations....   LEO
# 1             2                                              525.0   LEO
# 2             3                                              677.0   ISS
# 3             4                                              500.0    PO
# 4             5                                             3170.0   GTO
#
#      LaunchSite  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0  CCSFS SLC 40        1     False   False  False        NaN    1.0
# 1  CCSFS SLC 40        1     False   False  False        NaN    1.0
# 2  CCSFS SLC 40        1     False   False  False        NaN    1.0
# 3   VAFB SLC 4E        1     False   False  False        NaN    1.0
# 4  CCSFS SLC 40        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial
# 0            0  B0003
# 1            0  B0005
# 2            0  B0007
# 3            0  B1003
# 4            0  B1004

# %% [markdown]
#  ### Create dummy variables to categorical columns

# %% [markdown]
# Use the function <code>get_dummies</code> and <code>features</code> dataframe to apply OneHotEncoder to the column <code>Orbits</code>, <code>LaunchSite</code>, <code>LandingPad</code>, and <code>Serial</code>. Assign the value to the variable <code>features_one_hot</code>, display the results using the method head. Your result dataframe must include all features including the encoded ones.

# %%
features.head()
# Out:
#    FlightNumber                                        PayloadMass Orbit  \
# 0             1  <bound method NDFrame._add_numeric_operations....   LEO
# 1             2                                              525.0   LEO
# 2             3                                              677.0   ISS
# 3             4                                              500.0    PO
# 4             5                                             3170.0   GTO
#
#      LaunchSite  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0  CCSFS SLC 40        1     False   False  False        NaN    1.0
# 1  CCSFS SLC 40        1     False   False  False        NaN    1.0
# 2  CCSFS SLC 40        1     False   False  False        NaN    1.0
# 3   VAFB SLC 4E        1     False   False  False        NaN    1.0
# 4  CCSFS SLC 40        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial
# 0            0  B0003
# 1            0  B0005
# 2            0  B0007
# 3            0  B1003
# 4            0  B1004

# %%
features_one_hot = pd.get_dummies(features,columns=['LaunchSite','Orbit','LandingPad','Serial'])

# %% [markdown]
# ### Cast all numeric columns to `float64`

# %% [markdown]
# Now that our <code>features_one_hot</code> dataframe only contains numbers cast the entire dataframe to variable type <code>float64</code>

# %%
# HINT: use astype function
features_one_hot.replace(False,0,inplace=True)
features_one_hot.replace(True,1,inplace=True)

# %%
features_one_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 80 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   FlightNumber                         90 non-null     int64
#  1   PayloadMass                          90 non-null     object
#  2   Flights                              90 non-null     int64
#  3   GridFins                             90 non-null     int64
#  4   Reused                               90 non-null     int64
#  5   Legs                                 90 non-null     int64
#  6   Block                                90 non-null     float64
#  7   ReusedCount                          90 non-null     int64
#  8   LaunchSite_CCSFS SLC 40              90 non-null     uint8
#  9   LaunchSite_KSC LC 39A                90 non-null     uint8
#  10  LaunchSite_VAFB SLC 4E               90 non-null     uint8
#  11  Orbit_ES-L1                          90 non-null     uint8
#  12  Orbit_GEO                            90 non-null     uint8
#  13  Orbit_GTO                            90 non-null     uint8
#  14  Orbit_HEO                            90 non-null     uint8
#  15  Orbit_ISS                            90 non-null     uint8
#  16  Orbit_LEO                            90 non-null     uint8
#  17  Orbit_MEO                            90 non-null     uint8
#  18  Orbit_PO                             90 non-null     uint8
#  19  Orbit_SO                             90 non-null     uint8
#  20  Orbit_SSO                            90 non-null     uint8
#  21  Orbit_VLEO                           90 non-null     uint8
#  22  LandingPad_5e9e3032383ecb267a34e7c7  90 non-null     uint8
#  23  LandingPad_5e9e3032383ecb554034e7c9  90 non-null     uint8
#  24  LandingPad_5e9e3032383ecb6bb234e7ca  90 non-null     uint8
#  25  LandingPad_5e9e3032383ecb761634e7cb  90 non-null     uint8
#  26  LandingPad_5e9e3033383ecbb9e534e7cc  90 non-null     uint8
#  27  Serial_B0003                         90 non-null     uint8
#  28  Serial_B0005                         90 non-null     uint8
#  29  Serial_B0007                         90 non-null     uint8
#  30  Serial_B1003                         90 non-null     uint8
#  31  Serial_B1004                         90 non-null     uint8
#  32  Serial_B1005                         90 non-null     uint8
#  33  Serial_B1006                         90 non-null     uint8
#  34  Serial_B1007                         90 non-null     uint8
#  35  Serial_B1008                         90 non-null     uint8
#  36  Serial_B1010                         90 non-null     uint8
#  37  Serial_B1011                         90 non-null     uint8
#  38  Serial_B1012                         90 non-null     uint8
#  39  Serial_B1013                         90 non-null     uint8
#  40  Serial_B1015                         90 non-null     uint8
#  41  Serial_B1016                         90 non-null     uint8
#  42  Serial_B1017                         90 non-null     uint8
#  43  Serial_B1018                         90 non-null     uint8
#  44  Serial_B1019                         90 non-null     uint8
#  45  Serial_B1020                         90 non-null     uint8
#  46  Serial_B1021                         90 non-null     uint8
#  47  Serial_B1022                         90 non-null     uint8
#  48  Serial_B1023                         90 non-null     uint8
#  49  Serial_B1025                         90 non-null     uint8
#  50  Serial_B1026                         90 non-null     uint8
#  51  Serial_B1028                         90 non-null     uint8
#  52  Serial_B1029                         90 non-null     uint8
#  53  Serial_B1030                         90 non-null     uint8
#  54  Serial_B1031                         90 non-null     uint8
#  55  Serial_B1032                         90 non-null     uint8
#  56  Serial_B1034                         90 non-null     uint8
#  57  Serial_B1035                         90 non-null     uint8
#  58  Serial_B1036                         90 non-null     uint8
#  59  Serial_B1037                         90 non-null     uint8
#  60  Serial_B1038                         90 non-null     uint8
#  61  Serial_B1039                         90 non-null     uint8
#  62  Serial_B1040                         90 non-null     uint8
#  63  Serial_B1041                         90 non-null     uint8
#  64  Serial_B1042                         90 non-null     uint8
#  65  Serial_B1043                         90 non-null     uint8
#  66  Serial_B1044                         90 non-null     uint8
#  67  Serial_B1045                         90 non-null     uint8
#  68  Serial_B1046                         90 non-null     uint8
#  69  Serial_B1047                         90 non-null     uint8
#  70  Serial_B1048                         90 non-null     uint8
#  71  Serial_B1049                         90 non-null     uint8
#  72  Serial_B1050                         90 non-null     uint8
#  73  Serial_B1051                         90 non-null     uint8
#  74  Serial_B1054                         90 non-null     uint8
#  75  Serial_B1056                         90 non-null     uint8
#  76  Serial_B1058                         90 non-null     uint8
#  77  Serial_B1059                         90 non-null     uint8
#  78  Serial_B1060                         90 non-null     uint8
#  79  Serial_B1062                         90 non-null     uint8
# dtypes: float64(1), int64(6), object(1), uint8(72)
# memory usage: 12.1+ KB

# %%
# change from int to float64
features_one_hot['PayloadMass'] = pd.to_numeric(features_one_hot['PayloadMass'], errors='coerce')

# %%
features_one_hot= features_one_hot.astype('float64')

# %%
features_one_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 80 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   FlightNumber                         90 non-null     float64
#  1   PayloadMass                          85 non-null     float64
#  2   Flights                              90 non-null     float64
#  3   GridFins                             90 non-null     float64
#  4   Reused                               90 non-null     float64
#  5   Legs                                 90 non-null     float64
#  6   Block                                90 non-null     float64
#  7   ReusedCount                          90 non-null     float64
#  8   LaunchSite_CCSFS SLC 40              90 non-null     float64
#  9   LaunchSite_KSC LC 39A                90 non-null     float64
#  10  LaunchSite_VAFB SLC 4E               90 non-null     float64
#  11  Orbit_ES-L1                          90 non-null     float64
#  12  Orbit_GEO                            90 non-null     float64
#  13  Orbit_GTO                            90 non-null     float64
#  14  Orbit_HEO                            90 non-null     float64
#  15  Orbit_ISS                            90 non-null     float64
#  16  Orbit_LEO                            90 non-null     float64
#  17  Orbit_MEO                            90 non-null     float64
#  18  Orbit_PO                             90 non-null     float64
#  19  Orbit_SO                             90 non-null     float64
#  20  Orbit_SSO                            90 non-null     float64
#  21  Orbit_VLEO                           90 non-null     float64
#  22  LandingPad_5e9e3032383ecb267a34e7c7  90 non-null     float64
#  23  LandingPad_5e9e3032383ecb554034e7c9  90 non-null     float64
#  24  LandingPad_5e9e3032383ecb6bb234e7ca  90 non-null     float64
#  25  LandingPad_5e9e3032383ecb761634e7cb  90 non-null     float64
#  26  LandingPad_5e9e3033383ecbb9e534e7cc  90 non-null     float64
#  27  Serial_B0003                         90 non-null     float64
#  28  Serial_B0005                         90 non-null     float64
#  29  Serial_B0007                         90 non-null     float64
#  30  Serial_B1003                         90 non-null     float64
#  31  Serial_B1004                         90 non-null     float64
#  32  Serial_B1005                         90 non-null     float64
#  33  Serial_B1006                         90 non-null     float64
#  34  Serial_B1007                         90 non-null     float64
#  35  Serial_B1008                         90 non-null     float64
#  36  Serial_B1010                         90 non-null     float64
#  37  Serial_B1011                         90 non-null     float64
#  38  Serial_B1012                         90 non-null     float64
#  39  Serial_B1013                         90 non-null     float64
#  40  Serial_B1015                         90 non-null     float64
#  41  Serial_B1016                         90 non-null     float64
#  42  Serial_B1017                         90 non-null     float64
#  43  Serial_B1018                         90 non-null     float64
#  44  Serial_B1019                         90 non-null     float64
#  45  Serial_B1020                         90 non-null     float64
#  46  Serial_B1021                         90 non-null     float64
#  47  Serial_B1022                         90 non-null     float64
#  48  Serial_B1023                         90 non-null     float64
#  49  Serial_B1025                         90 non-null     float64
#  50  Serial_B1026                         90 non-null     float64
#  51  Serial_B1028                         90 non-null     float64
#  52  Serial_B1029                         90 non-null     float64
#  53  Serial_B1030                         90 non-null     float64
#  54  Serial_B1031                         90 non-null     float64
#  55  Serial_B1032                         90 non-null     float64
#  56  Serial_B1034                         90 non-null     float64
#  57  Serial_B1035                         90 non-null     float64
#  58  Serial_B1036                         90 non-null     float64
#  59  Serial_B1037                         90 non-null     float64
#  60  Serial_B1038                         90 non-null     float64
#  61  Serial_B1039                         90 non-null     float64
#  62  Serial_B1040                         90 non-null     float64
#  63  Serial_B1041                         90 non-null     float64
#  64  Serial_B1042                         90 non-null     float64
#  65  Serial_B1043                         90 non-null     float64
#  66  Serial_B1044                         90 non-null     float64
#  67  Serial_B1045                         90 non-null     float64
#  68  Serial_B1046                         90 non-null     float64
#  69  Serial_B1047                         90 non-null     float64
#  70  Serial_B1048                         90 non-null     float64
#  71  Serial_B1049                         90 non-null     float64
#  72  Serial_B1050                         90 non-null     float64
#  73  Serial_B1051                         90 non-null     float64
#  74  Serial_B1054                         90 non-null     float64
#  75  Serial_B1056                         90 non-null     float64
#  76  Serial_B1058                         90 non-null     float64
#  77  Serial_B1059                         90 non-null     float64
#  78  Serial_B1060                         90 non-null     float64
#  79  Serial_B1062                         90 non-null     float64
# dtypes: float64(80)
# memory usage: 56.4 KB

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section,but to make the answers consistent, in the next lab we will provide data in a pre-selected date range.

# %% [markdown]
# <code>features_one_hot.to_csv('dataset_part_3.csv', index=False)</code>

# %%
feature_one_hot.to_csv('dataset_part_3.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9120\2311770373.py in <module>
# ----> 1 feature_one_hot.to_csv('dataset_part_3.csv', index=False)
#
# NameError: name 'feature_one_hot' is not defined
